# %% [markdown]
# # AV 4 - Atuadores Elétricos, Hidráulicos e Pneumáticos

# %% [markdown]
# <img src="../images/AV4/1.png" alt="Questão 1" size="100%" position="center"/>
#
# <img src="../images/AV4/2.png" alt="Questão 2" size="100%" position="center"/>
#
# <img src="../images/AV4/3.png" alt="Questão 3" size="100%" position="center"/>
#
# <img src="../images/AV4/4.png" alt="Questão 4" size="100%" position="center"/>
#
# <img src="../images/AV4/5.png" alt="Questão 5" size="100%" position="center"/>
#
# <img src="../images/AV4/6.png" alt="Questão 6" size="100%" position="center"/>
#
# <img src="../images/AV4/7.png" alt="Questão 7" size="100%" position="center"/>
#
# <img src="../images/AV4/8.png" alt="Questão 8" size="100%" position="center"/>
#
# <img src="../images/AV4/9.png" alt="Questão 9" size="100%" position="center"/>
#
# <img src="../images/AV4/10.png" alt="Questão 10" size="100%" position="center"/>
#
# <img src="../images/AV4/Nota.png" alt="Nota AV4" size="100%" position="center"/>
