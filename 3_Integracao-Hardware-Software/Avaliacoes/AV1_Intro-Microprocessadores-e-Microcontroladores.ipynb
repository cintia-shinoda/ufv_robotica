# %% [markdown]
# # AV 1 - Introdução a Microprocessadores e Microcontroladores

# %% [markdown]
# <img src="../images/AV1/1.png" alt="Questão 1" size="100%" position="center"/>
#
# <img src="../images/AV1/2.png" alt="Questão 2" size="100%" position="center"/>
#
# <img src="../images/AV1/3.png" alt="Questão 3" size="100%" position="center"/>
#
# <img src="../images/AV1/4.png" alt="Questão 4" size="100%" position="center"/>
#
# <img src="../images/AV1/5.png" alt="Questão 5" size="100%" position="center"/>
#
# <img src="../images/AV1/Nota.png" alt="Nota AV1" size="100%" position="center"/>
