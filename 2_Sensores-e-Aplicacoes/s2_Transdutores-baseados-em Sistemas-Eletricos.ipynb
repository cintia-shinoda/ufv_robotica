# %% [markdown]
# # Semana 2: Transdutores baseados em Sistemas Elétricos

# %% [markdown]
# ## 1. Extensômetros

# %% [markdown]
# ## 2. Ponte de Wheatstone

# %% [markdown]
# ## 3. Compensação de Temperatura

# %% [markdown]
# ## 4. Sensores de Força

# %% [markdown]
# ## 5. Sensores de Deslocamento
