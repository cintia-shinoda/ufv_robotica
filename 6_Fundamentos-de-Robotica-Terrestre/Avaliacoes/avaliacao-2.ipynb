# %% [markdown]
# # Avaliação 2

# %% [markdown]
# <img src="../images/avaliacao-2/0.png" width="100%" align="center" alt="Avaliação 2 - Heading" />

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-2/1.png" width="100%" align="center" alt="Avaliação 2 - Questão 1" />

# %% [markdown]
# <img src="../images/avaliacao-2/2.png" width="100%" align="center" alt="Avaliação 2 - Questão 2" />

# %% [markdown]
# <img src="../images/avaliacao-2/3.png" width="100%" align="center" alt="Avaliação 2 - Questão 3" />

# %% [markdown]
# <img src="../images/avaliacao-2/4.png" width="100%" align="center" alt="Avaliação 2 - Questão 4" />

# %% [markdown]
# <img src="../images/avaliacao-2/resultado-2.png" width="100%" align="center" alt="Avaliação 2 - Resultado" />
