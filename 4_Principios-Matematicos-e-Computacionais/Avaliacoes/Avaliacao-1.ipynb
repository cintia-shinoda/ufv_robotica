# %% [markdown]
# # Avaliação 1

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-1/1-a.png" width="100%" align="center" />
# <img src="../images/avaliacao-1/1-b.png" width="100%" align="center" />

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/avaliacao-1/2-a.png" width="100%" align="center">
# <img src="../images/avaliacao-1/2-b.png" width="100%" align="center">

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/avaliacao-1/3.png" width="100%" align="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/avaliacao-1/4-a.png" width="100%" align="center" />
# <img src="../images/avaliacao-1/4-b.png" width="100%" align="center" />

# %% [markdown]
# <img src="../images/avaliacao-1/resultado-1.png" width="100%" align="center" alt="Avaliação 1 - Resultado 1" />
