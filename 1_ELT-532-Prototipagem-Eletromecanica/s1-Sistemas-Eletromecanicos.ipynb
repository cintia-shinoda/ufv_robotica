# %% [markdown]
# # Semana 1: Sistemas Eletromecânicos

# %% [markdown]
# ## Guia de Estudos
#
# - [ ] Vídeo-Aula 0 - Boas vindas e apresentação dos professores
# - [ ] Leitura: Introdução à Prototipagem Eletromecânica
# - [ ] Vídeo-Aula 1 - Visão Geral sobre Prototipagem Eletromecânica
# - [ ] Leitura: Seleção de Materiais
# - [ ] Vídeo-Aula 2 - Seleção de Materiais para Prototipagem Mecânica
# - [ ] Vídeo-Aula - Como criar uma conta na plataforma de modelagem Onshape
# - [x] Questionário - Semana 1

# %% [markdown]
# ## 1.1 Visão Geral da Prototipagem Eletromecânica
# ### 1.1.1 Fundamentos de Sistemas Eletromecânicos
#
#
# ## 1.2 Introdução aos componentes básicos de prototipagem
# ### 1.2.1 Sensores
# ### 1.2.2 Atuadores
# ### 1.2.3 Acessórios Computacionais para Modelagem 3D
# ### 1.2.4 Microcontroladores e Microprocessadores
# ### 1.2.5 Detalhes Adicionais sobre Acessórios Computacionais
# ### 1.2.6 Principais Programas e Softwares usados para a Eletrônica Básica
