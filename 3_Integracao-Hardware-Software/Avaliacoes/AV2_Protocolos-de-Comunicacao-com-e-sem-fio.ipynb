# %% [markdown]
# # AV2 - Protocolos de Comunicação e Exemplos com e sem fio

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/AV2/1.png" alt="Questão 1" size="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/AV2/2.png" alt="Questão 2" size="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/AV2/3.png" alt="Questão 3" size="100%" position="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="imagens/AV2/4.png" alt="Questão 4" size="100%" position="center"/>

# %% [markdown]
# ## 5

# %% [markdown]
# <img src="../images/AV2/5.png" alt="Questão 5" size="100%" position="center"/>

# %% [markdown]
# ## 6

# %% [markdown]
# <img src="../images/AV2/6.png" alt="Questão 6" size="100%" position="center"/>

# %% [markdown]
# ## 7

# %% [markdown]
# <img src="../images/AV2/7.png" alt="Questão 7" size="100%" position="center"/>

# %% [markdown]
# ## 8

# %% [markdown]
# <img src="../images/AV2/8.png" alt="Questão 8" size="100%" position="center"/>
