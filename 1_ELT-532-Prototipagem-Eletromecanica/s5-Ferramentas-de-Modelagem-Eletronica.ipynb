# %% [markdown]
# # Semana 5: Ferramentas de Modelagem Eletrônica

# %% [markdown]
# ## Guia de Estudos
#
# - [ ] Leitura: Seção 5.1 - Introdução a software de projeto eletrônico assistido por computador
# - [ ] Leitura: Seção 5.2 - Uso de placas de circuito impresso (PCSs)
# - [ ] Leitura: Seção 5.3 - Integração de componentes eletrônicos em um protótipo
# - [ ] Leitura: Seção 5.4 - Soldagem e montagem de componentes eletrônicos em PCBs
# - [ ] Vídeo-aula

# %% [markdown]
# ##  5.1 Introdução a Software de Projeto Eletrônico Assistido por Computador
# ## 5.2 Uso de Placas de Circuito Impresso (PCBs)
# ## 5.3 Integração de Componentes Eletromecânicos em um Protótipo
# ## 5.4 Soldagem e Montagem de Componentes Eletrônicos em PCBs
