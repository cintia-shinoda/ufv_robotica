# %% [markdown]
# # Avaliação 2

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-2/1.png" width="100%" align="center" alt="Avaliação 2 - Questão 1" />

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/avaliacao-2/2-a.png" width="100%" align="center" alt="Avaliação 2 - Questão 2-a" />
#
# <img src="../images/avaliacao-2/2-b.png" width="100%" align="center" alt="Avaliação 2 - Questão 2-b" />

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/avaliacao-2/3-a.png" width="100%" align="center" alt="Avaliação 2 - Questão 3-a" />
#
# <img src="../images/avaliacao-2/3-b.png" width="100%" align="center" alt="Avaliação 2 - Questão 3-b" />
#
# <img src="../images/avaliacao-2/3-c-1.png" width="100%" align="center" alt="Avaliação 2 - Questão 3-c-1" />
# <img src="../images/avaliacao-2/3-c-2.png" width="100%" align="center" alt="Avaliação 2 - Questão 3-c-2" />
#
# <img src="../images/avaliacao-2/3-d.png" width="100%" align="center" alt="Avaliação 2 - Questão 3-d" />

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/avaliacao-2/4.png" width="100%" align="center" alt="Avaliação 2 - Questão 4" />

# %% [markdown]
# <img src="../images/avaliacao-2/resultado-2.png" width="100%" align="center" alt="Avaliação 2 - Resultado" />
