# %% [markdown]
# # Semana 3 - Cinemática da Posição e Notação de Denavit-Hartenberg

# %% [markdown]
# ## Guia de Estudos

# %% [markdown]
# ## Apostila

# %% [markdown]
# ## Scripts de Referência

# %% [markdown]
# ```bash
# Interface/
# ├── Cinemática Direta/
# │   ├── CalcularDH.m
# │   ├── CalcularDHv2.m
# │   ├── CalcularDHv3.m
# │   ├── CalcularJacobiano.m
# │   ├── CinematicaDireta.m
# │   └── mArrow3.m
# ├── Sistemas de Referência/
# │   ├── arrow.m
# │   ├── arrow3d.m
# │   ├── RotacaoFixoCorrente.m
# │   ├── RotacaoFixoCorrenteAjuda.txt
# │   ├── RotacaoFixoCorrenteExecutar.m
# │   ├── RotacaoFixoCorrenteOrigem.m
# │   └── rotatedata.m
# └── ELT535Robotica.m
# ```

# %% [markdown]
# ## Live

# %% [markdown]
# ## Avaliação da Semana 3

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-3/0.png" alt="Atividade Avaliativa 3 - Heading" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-3/1.png" alt="Atividade Avaliativa 3 - Questão 1" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-3/2.png" alt="Atividade Avaliativa 3 - Questão 2" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-3/3.png" alt="Atividade Avaliativa 3 - Questão 3" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-3/4-a.png" alt="Atividade Avaliativa 3 - Questão 4-a" width="100%" align="center"/>
#
# <img src="./images/atividades-avaliativas/semana-3/4-b.png" alt="Atividade Avaliativa 3 - Questão 4-b" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-3/5-a.png" alt="Atividade Avaliativa 3 - Questão 5-a" width="100%" align="center"/>
#
# <img src="./images/atividades-avaliativas/semana-3/5-b.png" alt="Atividade Avaliativa 3 - Questão 5-b" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-3/atividade-3-resultado.png" alt="Atividade Avaliativa 3 - Resultado" width="100%" align="center"/>
