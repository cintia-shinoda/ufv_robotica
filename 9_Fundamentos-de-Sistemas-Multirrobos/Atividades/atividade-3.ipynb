# %% [markdown]
# # Atividade 3

# %% [markdown]
# <img src="../images/atividade-3/0.png" width="100%" align="center" alt="Atividade 3 - Heading"/>

# %% [markdown]
# <img src="../images/atividade-3/1.png" width="100%" align="center" alt="Atividade 3 - Questão 1"/>

# %% [markdown]
# <img src="../images/atividade-3/2.png" width="100%" align="center" alt="Atividade 3 - Questão 2"/>

# %% [markdown]
# <img src="../images/atividade-3/3.png" width="100%" align="center" alt="Atividade 3 - Questão 3"/>

# %% [markdown]
# <img src="../images/atividade-3/atividade-3-resultado.png" width="100%" align="center" alt="Atividade 3 - Resultado"/>
