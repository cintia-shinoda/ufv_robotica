# %% [markdown]
# ```matlab
# % for i = 2:30
# %     disp('Hello World')
# % end
#
#
#
# % declarar variáveis
# r = 34;
# w = 6;
# y = 23;
#
# disp(pi)
# disp(j)
# disp(5j)
#
# % vetor
# y = 3;
# x = (2:30);
# disp(x);
# plot(x,y);
#
#
# close all;
# ```
