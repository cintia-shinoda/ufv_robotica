# %% [markdown]
# # Avaliação 2

# %% [markdown]
# <img src="../images/avaliacao-2/0.png" alt="Avaliação 2 - Heading" width="100%" position="center"/>

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-2/1.png" alt="Avaliação 2 - Questão 1" width="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/avaliacao-2/2.png" alt="Avaliação 2 - Questão 2" width="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/avaliacao-2/3.png" alt="Avaliação 2 - Questão 3" width="100%" position="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/avaliacao-2/4.png" alt="Avaliação 2 - Questão 4" width="100%" position="center"/>

# %% [markdown]
# <img src="../images/avaliacao-2/avaliacao-2-resultado.png" alt="Avaliação 2 - Resultado" width="100%" position="center"/>
