# %% [markdown]
# # Questionário 5 e 6

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/questionario-5-6/1.png" alt="Questão 1" size="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/questionario-5-6/2.png" alt="Questão 2" size="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/questionario-5-6/3.png" alt="Questão 3" size="100%" position="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/questionario-5-6/4.png" alt="Questão 4" size="100%" position="center"/>

# %% [markdown]
# ## 5

# %% [markdown]
# <img src="../images/questionario-5-6/5.png" alt="Questão 5" size="100%" position="center"/>

# %% [markdown]
# ## 6

# %% [markdown]
# <img src="../images/questionario-5-6/6.png" alt="Questão 6" size="100%" position="center"/>
