# %% [markdown]
# # Atividade 4

# %% [markdown]
# <img src="../images/atividade-4/0.png" width="100%" align="center" alt="Atividade 4 - Heading"/>

# %% [markdown]
# <img src="../images/atividade-4/1.png" width="100%" align="center" alt="Atividade 4 - Questão 1"/>

# %% [markdown]
# <img src="../images/atividade-4/2.png" width="100%" align="center" alt="Atividade 4 - Questão 2"/>

# %% [markdown]
# <img src="../images/atividade-4/3-a.png" width="100%" align="center" alt="Atividade 4 - Questão 3-a"/>
#
# <img src="../images/atividade-4/3-b.png" width="100%" align="center" alt="Atividade 4 - Questão 3-b"/>

# %% [markdown]
# <img src="../images/atividade-4/atividade-4-resultado.png" width="100%" align="center" alt="Atividade 4 - Resultado"/>
