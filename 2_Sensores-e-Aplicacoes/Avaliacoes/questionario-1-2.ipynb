# %% [markdown]
# # Questionário 1 e 2

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/questionario-1-2/1.png" alt="Questão 1" size="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/questionario-1-2/2.png" alt="Questão 2" size="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/questionario-1-2/3.png" alt="Questão 3" size="100%" position="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/questionario-1-2/4.png" alt="Questão 4" size="100%" position="center"/>

# %% [markdown]
# ## 5

# %% [markdown]
# <img src="../images/questionario-1-2/5.png" alt="Questão 5" size="100%" position="center"/>

# %% [markdown]
# ## 6

# %% [markdown]
# <img src="../images/questionario-1-2/6.png" alt="Questão 6" size="100%" position="center"/>

# %% [markdown]
# ## 7

# %% [markdown]
# <img src="../images/questionario-1-2/7.png" alt="Questão 7" size="100%" position="center"/>

# %% [markdown]
# ## 8

# %% [markdown]
# <img src="../images/questionario-1-2/8.png" alt="Questão 8" size="100%" position="center"/>

# %% [markdown]
# ## 9

# %% [markdown]
# <img src="../images/questionario-1-2/9.png" alt="Questão 9" size="100%" position="center"/>

# %% [markdown]
# ## 10

# %% [markdown]
# <img src="../images/questionario-1-2/10.png" alt="Questão 10" size="100%" position="center"/>
