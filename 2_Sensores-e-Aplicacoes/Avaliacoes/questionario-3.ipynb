# %% [markdown]
# # Questionário 3

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/questionario-3/1.png" alt="Questão 1" size="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/questionario-3/2.png" alt="Questão 2" size="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/questionario-3/3.png" alt="Questão 3" size="100%" position="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/questionario-3/4.png" alt="Questão 4" size="100%" position="center"/>

# %% [markdown]
# ## 5

# %% [markdown]
# <img src="../images/questionario-3/5.png" alt="Questão 5" size="100%" position="center"/>
