# %% [markdown]
# # 2. CoppeliaSim

# %% [markdown]
# Tutorial básico da instalação e operação: https://drive.google.com/open?id=1YbJYp4xqvc4pFw8IwBLnLEbQHCd92dt3&usp=drive_fs
#
# ```bash
# pip install -r requirements.txt
# ```
