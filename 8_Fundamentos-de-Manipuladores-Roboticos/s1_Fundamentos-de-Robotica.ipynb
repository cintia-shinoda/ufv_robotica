# %% [markdown]
# # Semana 1 - Fundamentos de Robótica

# %% [markdown]
# ## Guia de Estudos da Semana 1

# %% [markdown]
# ## Apostila de Fundamentos de Robótica

# %% [markdown]
# ## Live 1

# %% [markdown]
# - 14/07/2026

# %% [markdown]
# ## Mão na Massa: Manipuladores na Prática

# %% [markdown]
# ### 1. Introdução ao Robotics Toolbox no Matlab

# %% [markdown]
# ### 2. Conhecendo Graus de Liberdade e Construindo o Próprio Robô

# %% [markdown]
# ### 3. Juntas, Efetuador e Espaço de Trabalho

# %% [markdown]
# ## Exercícios da Semana 1

# %% [markdown]
# ## Avaliação da Semana 1

# %% [markdown]
# <img src="images/atividades-avaliativas/semana-1/1.png" width="100%" align="center" />

# %% [markdown]
# <img src="images/atividades-avaliativas/semana-1/2.png" width="100%" align="center" />

# %% [markdown]
# <img src="images/atividades-avaliativas/semana-1/3.png" width="100%" align="center" />

# %% [markdown]
# <img src="images/atividades-avaliativas/semana-1/4.png" width="100%" align="center" />

# %% [markdown]
# <img src="images/atividades-avaliativas/semana-1/5-a.png" width="100%" align="center" />
#
# <img src="images/atividades-avaliativas/semana-1/5-b.png" width="100%" align="center" />
