# %% [markdown]
# # Avaliação 4

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-4/1.png" width="100%" align="center" alt="Avaliação 4 - Questão 1" />

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/avaliacao-4/2-a.png" width="100%" align="center" alt="Avaliação 4 - Questão 2-a" />
#
# <img src="../images/avaliacao-4/2-b.png" width="100%" align="center" alt="Avaliação 4 - Questão 2-b" />

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/avaliacao-4/3.png" width="100%" align="center" alt="Avaliação 4 - Questão 3" />

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/avaliacao-4/4.png" width="100%" align="center" alt="Avaliação 4 - Questão 4" />

# %% [markdown]
# <img src="../images/avaliacao-4/resultado-4.png" width="100%" align="center" alt="Avaliação 4 - Resultado 4" />
