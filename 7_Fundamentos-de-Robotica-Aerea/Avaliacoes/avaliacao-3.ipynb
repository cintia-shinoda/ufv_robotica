# %% [markdown]
# # Avaliação 3

# %% [markdown]
# <img src="../images/avaliacao-3/0.png" alt="Avaliação 3 - Heading" width="100%" position="center"/>

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-3/1.png" alt="Avaliação 3 - Questão 1" width="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/avaliacao-3/2.png" alt="Avaliação 3 - Questão 2" width="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/avaliacao-3/3.png" alt="Avaliação 3 - Questão 3" width="100%" position="center"/>
