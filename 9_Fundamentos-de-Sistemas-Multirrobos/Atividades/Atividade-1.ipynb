# %% [markdown]
# # Atividade 1

# %% [markdown]
# <img src="../images/atividade-1/0.png" width="100%" align="center" alt="Atividade 1 - Heading"/>

# %% [markdown]
# <img src="../images/atividade-1/1.png" width="100%" align="center" alt="Atividade 1 - Questão 1"/>

# %% [markdown]
# <img src="../images/atividade-1/2.png" width="100%" align="center" alt="Atividade 1 - Questão 2"/>

# %% [markdown]
# <img src="../images/atividade-1/3.png" width="100%" align="center" alt="Atividade 1 - Questão 3"/>
