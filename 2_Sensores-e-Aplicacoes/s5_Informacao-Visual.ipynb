# %% [markdown]
# # Semana 5: Informação Visual

# %% [markdown]
# ## 1. Câmera RGB

# %% [markdown]
# ## 2. Câmera Estéreo

# %% [markdown]
# ## 3. Câmera Multiespectral

# %% [markdown]
# ## 4. Câmera RGB-D

# %% [markdown]
# ## 5. Câmera Térmica
