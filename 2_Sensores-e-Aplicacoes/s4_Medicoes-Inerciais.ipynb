# %% [markdown]
# # Semana 4: Medições Inerciais

# %% [markdown]
# ## 1. Bússola / Magnetômetro

# %% [markdown]
# ## 2. Barômetro

# %% [markdown]
# ## 3. Acelerômetro

# %% [markdown]
# ## 4. Giroscópio

# %% [markdown]
# ## 5. Unidades de Medição Inercial (IMU)
