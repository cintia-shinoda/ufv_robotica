# %% [markdown]
# ## Apostilas

# %% [markdown]
# - Sistemas No Lineales - Gustavo Vitorino Monteiro da Silva
# - Sistemas No Lineales - María Marta Seron

# %% [markdown]
# ## Monografias, Dissertações e Teses

# %% [markdown]
# - TCC - Análise Preliminar de SNL - Bárbara C. Araújo
# - TCC - Comparação de Controladores de Altitude e Guinada - Alexandre Fernandes
# - TCC - Consenso usando MUAV - Thais Bento
# - TCC - Reconfiguração de MUAV - João Paulo Barbosa
# - TD - Projeto de Controladores - Alexandre S. Brandão

# %% [markdown]
# ## Artigos Científicos

# %% [markdown]
# - PVTOL maneuvers guided by a high-level nonlinear controller applied to a rotorcraft machine
# - 3-D Positioning Tasks for RUAS Using Switched PVTOL Controllers
# - Modelagem e Controle Não Linear Subatuado de um Quad-rotor: Parte 1
# - Modelagem e Controle Não Linear Subatuado de um Quad-rotor: Parte 2
# - Modelling and Control of a PVTOL Quadrotor Carrying a Suspended Load
# - On the Guidance of Multiple UAV Using a Centralized Formation Control Scheme and Delaunay Triangulation
# - Navigation and Cooperative Control Using the AR.Drone Quadrotor
# - Outdoor Waypoint Navigation with the AR.Drone Quadrotor
# - High-Level Underactuated Nonlinear Control for Rotorcraft Machines
# - High-Level Modeling and Control of the Bebop 2 Micro Aerial Vehicle
