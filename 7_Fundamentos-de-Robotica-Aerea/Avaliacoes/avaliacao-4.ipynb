# %% [markdown]
# # Avaliação 4

# %% [markdown]
# <img src="../images/avaliacao-4/0.png" alt="Avaliação 4 - Heading" width="100%" position="center"/>

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-4/1.png" alt="Avaliação 4 - Questão 1" width="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/avaliacao-4/2.png" alt="Avaliação 4 - Questão 2" width="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/avaliacao-4/3.png" alt="Avaliação 4 - Questão 3" width="100%" position="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/avaliacao-4/4.png" alt="Avaliação 4 - Questão 4" width="100%" position="center"/>

# %% [markdown]
# <img src="../images/avaliacao-4/avaliacao-4-resultado.png" alt="Avaliação 4 - Resultado" width="100%" position="center"/>
