# %% [markdown]
# # Semana 4 -

# %% [markdown]
# ## Atividade Avaliativa 4

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-4/0.png" alt="Atividade Avaliativa 4 - Heading" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-4/1.png" alt="Atividade Avaliativa 4 - Questão 1" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-4/2.png" alt="Atividade Avaliativa 4 - Questão 2" width="100%" align="center"/>

# %% [markdown]
# <img src="./images/atividades-avaliativas/semana-4/3-a.png" alt="Atividade Avaliativa 4 - Questão 3-a" width="100%" align="center"/>
#
# <img src="./images/atividades-avaliativas/semana-4/3-b.png" alt="Atividade Avaliativa 4 - Questão 3-b" width="100%" align="center"/>
