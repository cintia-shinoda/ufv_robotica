# %% [markdown]
# # Avaliação 2

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/questionario-2/1.png" alt="Questionário 2 - Questão 1" size="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/questionario-2/2.png" alt="Questionário 2 - Questão 2" size="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/questionario-2/3.png" alt="Questionário 2 -     Questão 3" size="100%" position="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/questionario-2/4.png" alt="Questionário 2 - Questão 4" size="100%" position="center"/>

# %% [markdown]
# ## 5

# %% [markdown]
# <img src="../images/questionario-2/5.png" alt="Questionário 2 - Questão 5" size="100%" position="center"/>
