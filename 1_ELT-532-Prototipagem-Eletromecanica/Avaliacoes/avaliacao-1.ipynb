# %% [markdown]
# # Avaliação 1

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/questionario-1/1.png" alt="Questionário 1 - Questão 1" size="100%" position="center"/>

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/questionario-1/2.png" alt="Questionário 1 - Questão 2" size="100%" position="center"/>

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/questionario-1/3.png" alt="Questionário 1 - Questão 3" size="100%" position="center"/>

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/questionario-1/4.png" alt="Questionário 1 - Questão 4" size="100%" position="center"/>

# %% [markdown]
# ## 5

# %% [markdown]
# <img src="../images/questionario-1/5.png" alt="Questionário 1 - Questão 5" size="100%" position="center"/>
