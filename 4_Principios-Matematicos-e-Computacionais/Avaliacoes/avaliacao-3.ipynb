# %% [markdown]
# # Avaliação 3

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-3/1-a.png" width="100%" align="center" alt="Avaliação 3 - Questão 1-a" />
#
# <img src="../images/avaliacao-3/1-b.png" width="100%" align="center" alt="Avaliação 3 - Questão 1-b" />

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/avaliacao-3/2.png" width="100%" align="center" alt="Avaliação 3 - Questão 2" />

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/avaliacao-3/3.png" width="100%" align="center" alt="Avaliação 3 - Questão 3" />

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/avaliacao-3/4-a.png" width="100%" align="center" alt="Avaliação 3 - Questão 4-a" />
#
# <img src="../images/avaliacao-3/4-b.png" width="100%" align="center" alt="Avaliação 3 - Questão 4-b" />

# %% [markdown]
# <img src="../images/avaliacao-3/resultado-3.png" width="100%" align="center" alt="Avaliação 3 - Resultado" />
