# %% [markdown]
# # Avaliação 1

# %% [markdown]
# ## 1

# %% [markdown]
# <img src="../images/avaliacao-1/1.png" width="100%" align="center" alt="Avaliação 1 - Questão 1" />

# %% [markdown]
# ## 2

# %% [markdown]
# <img src="../images/avaliacao-1/2-a.png" width="100%" align="center" alt="Avaliação 1 - Questão 2-a" />
#
# <img src="../images/avaliacao-1/2-b.png" width="100%" align="center" alt="Avaliação 1 - Questão 2-a" />
#
# <img src="../images/avaliacao-1/2-c.png" width="100%" align="center" alt="Avaliação 1 - Questão 2-c" />
#
# <img src="../images/avaliacao-1/2-d.png" width="100%" align="center" alt="Avaliação 1 - Questão 2-d" />
#
# <img src="../images/avaliacao-1/2-e.png" width="100%" align="center" alt="Avaliação 1 - Questão 2-e" />

# %% [markdown]
# ## 3

# %% [markdown]
# <img src="../images/avaliacao-1/3.png" width="100%" align="center" alt="Avaliação 1 - Questão 3" />

# %% [markdown]
# ## 4

# %% [markdown]
# <img src="../images/avaliacao-1/4.png" width="100%" align="center" alt="Avaliação 1 - Questão 4" />

# %% [markdown]
# <img src="../images/avaliacao-1/resultado-1.png" width="100%" align="center" alt="Avaliação 1 - Resultado" />
