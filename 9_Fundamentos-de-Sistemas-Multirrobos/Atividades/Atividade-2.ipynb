# %% [markdown]
# # Atividade 2

# %% [markdown]
# <img src="../images/atividade-2/0.png" width="100%" align="center" alt="Atividade 2 - Heading"/>

# %% [markdown]
# <img src="../images/atividade-2/1.png" width="100%" align="center" alt="Atividade 2 - Questão 1"/>

# %% [markdown]
# <img src="../images/atividade-2/2-a.png" width="100%" align="center" alt="Atividade 2 - Questão 2-a"/>
#
# <img src="../images/atividade-2/2-b.png" width="100%" align="center" alt="Atividade 2 - Questão 2-b"/>

# %% [markdown]
# <img src="../images/atividade-2/3.png" width="100%" align="center" alt="Atividade 2 - Questão 3"/>

# %% [markdown]
# <img src="../images/atividade-2/4.png" width="100%" align="center" alt="Atividade 2 - Questão 4"/>

# %% [markdown]
# <img src="../images/atividade-2/atividade-2-resultado.png" width="100%" align="center" alt="Atividade 2 - Resultado"/>
