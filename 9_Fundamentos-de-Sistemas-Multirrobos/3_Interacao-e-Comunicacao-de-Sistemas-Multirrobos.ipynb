# %% [markdown]
# # 3. Interação e Comunicação de Sistemas Multirrobôs

# %% [markdown]
# ## Tipos de Interação
# - Coordenação x Cooperação x Colaboração`
#
# ## Comunicação de Sistemas Multirrobôs
# - Topologia, Endereçamento e Latência.
#
# ## Exemplos
